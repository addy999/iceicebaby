# %%
## Initializing the Sensor to Gather Data from it

import time
import board
import busio
import adafruit_mlx90640
import numpy as np 

# Setup the IR Camera; code form Adafruit Specs
i2c = busio.I2C(board.SCL, board.SDA, frequency=800000)
mlx = adafruit_mlx90640.MLX90640(i2c)
mlx.refresh_rate = adafruit_mlx90640.RefreshRate.REFRESH_2_HZ
print("Camera is ready")
 
#make a function to take 3 snapshots with the IR camera and average out the data
def get_data(snaps=3):
    all_snaps = []
    for i in range(snaps):
        capture = [0] * 768 #Camera grabs 768 pixels of info; 24x32
        mlx.getFrame(capture) #Gets the data in frame of the capture list
        all_snaps.append(np.array(capture)) #append captured data to a list     
    mean_array = np.mean(np.array(all_snaps), axis=0) #turn to a numpy array that's averaged 
    return np.reshape(mean_array, (24, 32)) #reshapes the output to the proper dataframe
# Out:
# Found 0 broken pixels, 0 outliers
# Camera is ready

# %%
while True:
    temperatures = get_data(1) #get the temperature data from the IR camera
    block = [temperatures[row][col] for col in range(32) for row in range(10,14)]
    print(max(np.array(block)))
#     print(np.mean(np.array(block)))
# Out:
# 28.246715779749593
# 28.08165684775787
# 27.922689336274743
# 28.144263201415015
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-d634c652afc7> in <module>
#       1 while True:
# ----> 2     temperatures = get_data(1) #get the temperature data from the IR camera
#       3     block = [temperatures[row][col] for col in range(32) for row in range(10,14)]
#       4     print(max(np.array(block)))
#       5 #     print(np.mean(np.array(block)))
#
# <ipython-input-18-0a081581b19c> in get_data(snaps)
#      18     for i in range(snaps):
#      19         capture = [0] * 768 #Camera grabs 768 pixels of info; 24x32
# ---> 20         mlx.getFrame(capture) #Gets the data in frame of the capture list
#      21         all_snaps.append(np.array(capture)) #append captured data to a list
#      22     mean_array = np.mean(np.array(all_snaps), axis=0) #turn to a numpy array that's averaged
#
# /usr/local/lib/python3.7/dist-packages/adafruit_mlx90640.py in getFrame(self, framebuf)
#     137
#     138         for _ in range(2):
# --> 139             status = self._GetFrameData(mlx90640Frame)
#     140             if status < 0:
#     141                 raise RuntimeError("Frame data error")
#
# /usr/local/lib/python3.7/dist-packages/adafruit_mlx90640.py in _GetFrameData(self, frameData)
#     151
#     152         while dataReady == 0:
# --> 153             self._I2CReadWords(0x8000, statusRegister)
#     154             dataReady = statusRegister[0] & 0x0008
#     155             #print("ready status: 0x%x" % dataReady)
#
# /usr/local/lib/python3.7/dist-packages/adafruit_mlx90640.py in _I2CReadWords(self, addr, buffer, end)
#     755                 addrbuf[1] = addr & 0xFF  # LSB
#     756                 read_words = min(remainingWords, I2C_READ_LEN)
# --> 757                 i2c.write_then_readinto(addrbuf, inbuf, in_end=read_words*2) # in bytes
#     758                 #print("-> ", [hex(i) for i in addrbuf])
#     759                 outwords = struct.unpack('>' + 'H' * read_words, inbuf[0:read_words*2])
#
# /usr/local/lib/python3.7/dist-packages/adafruit_bus_device/i2c_device.py in write_then_readinto(self, out_buffer, in_buffer, out_start, out_end, in_start, in_end, stop)
#     139             self.i2c.writeto_then_readfrom(self.device_address, out_buffer, in_buffer,
#     140                                            out_start=out_start, out_end=out_end,
# --> 141                                            in_start=in_start, in_end=in_end)
#     142
#     143         else:
#
# ~/.local/lib/python3.7/site-packages/busio.py in writeto_then_readfrom(self, address, buffer_out, buffer_in, out_start, out_end, in_start, in_end, stop)
#      89         return self._i2c.writeto_then_readfrom(address, buffer_out, buffer_in,
#      90                                                out_start=out_start, out_end=out_end,
# ---> 91                                                in_start=in_start, in_end=in_end, stop=stop)
#      92
#      93 class SPI(Lockable):
#
# ~/.local/lib/python3.7/site-packages/adafruit_blinka/microcontroller/generic_linux/i2c.py in writeto_then_readfrom(self, address, buffer_out, buffer_in, out_start, out_end, in_start, in_end, stop)
#      59         else:
#      60             # To generate without a stop, do in one block transaction
# ---> 61             readin = self._i2c_bus.read_i2c_block_data(address, buffer_out[out_start:out_end], in_end-in_start)
#      62             for i in range(in_end-in_start):
#      63                 buffer_in[i+in_start] = readin[i]
#
# ~/.local/lib/python3.7/site-packages/Adafruit_PureIO/smbus.py in read_i2c_block_data(self, addr, cmd, length)
#     225
#     226         # Make ioctl call and return result data.
# --> 227         ioctl(self._device.fileno(), I2C_RDWR, request)
#     228         return bytearray(result.raw)  # Use .raw instead of .value which will stop at a null byte!
#     229
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib notebook
import time

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111)

while True:
#     temperatures = np.random.random((24,32)) #test data to make sure things work
    temperatures = get_data(1) #get the temperature data from the IR camera
    heat = plt.imshow(temperatures, cmap='inferno', interpolation='nearest') #initialize the heatmap
    legend = plt.colorbar(heat) #make a legend for the captured data
    fig.canvas.draw() #plot the heatmap
    plt.title('Sensor Data Heatmap (oC)') 
    time.sleep(0.1) #take a sleep
    legend.remove() #remove the legend for the new legend to be added for the new data
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-c409d58d1c83> in <module>
#      14     heat = plt.imshow(temperatures, cmap='inferno', interpolation='nearest') #initialize the heatmap
#      15     legend = plt.colorbar(heat) #make a legend for the captured data
# ---> 16     fig.canvas.draw() #plot the heatmap
#      17     plt.title('Sensor Data Heatmap (oC)')
#      18     time.sleep(0.1) #take a sleep
#
# ~/.local/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
#     153             self.manager.refresh_all()  # Swap the frames.
#
# ~/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/.local/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/.local/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     617         else:
#     618             im, l, b, trans = self.make_image(
# --> 619                 renderer, renderer.get_image_magnification())
#     620             if im is not None:
#     621                 renderer.draw_image(gc, l, b, im)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     879         return self._make_image(
#     880             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 881             unsampled=unsampled)
#     882
#     883     def _check_unsampled_image(self, renderer):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     464                                 True, 1,
#     465                                 self.get_filternorm(),
# --> 466                                 self.get_filterrad())
#     467                 # we are done with the mask, delete from namespace to be sure!
#     468                 del mask
#
# KeyboardInterrupt:
