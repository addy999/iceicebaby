# %%
import sys, os
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
results_path = 'Results/'

# %%
# Load all tests
all_tests = [i for i in os.listdir(results_path)]
all_tests
# Out:
# ['1', '10', '11', '12', '13', '2', '3', '4', '5', '7', '8', '9']

# %%
def get_data(rock_id, seconds):
    ''' Returns array of temps @ 0 seconds and 10 seconds'''
    path = results_path + str(rock_id)
    files= os.listdir(path)    
    for file in files:
        if "_"+str(seconds) in file:
            f = open(path + "/" + file, "rb") 
    return np.load(f)

# %%
def view(rock_id):
    z, t = get_data(rock_id, 0), get_data(rock_id, 10)
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
    sns.heatmap(z, linewidth=0, ax=ax1)
    sns.heatmap(t, linewidth=0, ax=ax2)
    fig.set_size_inches(15, 5)
    fig.show()

def view_img(img):
    sns.heatmap(img, linewidth=0)
    plt.show()

# %% [markdown]
# # Analyze

# %%
view(1)

# %% [markdown]
# ### Get min, max and mean from given array

# %%
def crop(img, pixel_range = 5):
    x,y = img.shape
    mid_x, mid_y = int(x/2), int(y/2)
    row_indices = range(mid_x-pixel_range, mid_x+pixel_range)
    col_indices = range(mid_y-pixel_range, mid_y+pixel_range)
    cropped = []
    for row in row_indices:
        to_add = []
        cropped.append([])
        for col in col_indices:
            to_add.append(img[row, col])
        cropped[-1] = np.array(to_add)
    return np.array(cropped)
    
    
#     cropped_data = [img[row,col] for col in col_indices for row in row_indices]
#     return np.reshape(cropped_data, (pixel_range, pixel_range))

# %%
original = get_data(1,10)
cropped = crop(original, 4)
view_img(cropped)

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
# %matplotlib inline
im = cv2.imread('apple-256261_640.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
